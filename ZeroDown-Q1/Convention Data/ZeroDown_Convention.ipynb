# %%
# !pip install geopandas

# %%
# !pip install dnspython

# %%
# !pip install pymongo

# %%
import pymongo
import json
import pandas as pd
from pprint import pprint

# %%
data=pd.read_csv('/content/convention.csv')

# %%
data.head()
# Out:
#    Unnamed: 0             X             Y  OBJECTID  CONV_ID  \
# 0           0 -9.603671e+06  3.816326e+06         1       62
# 1           1 -1.276142e+07  3.850495e+06         2      200
# 2           2 -1.024107e+07  4.058537e+06         3      125
# 3           3 -1.027150e+07  4.129777e+06         4      106
# 4           4 -1.027195e+07  4.129855e+06         5      113
#
#                            NAME         CITY STATE       TELEPHONE  \
# 0          THE GARRETT COLISEUM   MONTGOMERY    AL  (334) 356-6866
# 1             YUMA CIVIC CENTER         YUMA    AZ  (928) 373-5040
# 2  PINE BLUFF CONVENTION CENTER   PINE BLUFF    AR  (870) 536-7600
# 3  STATEHOUSE CONVENTION CENTER  LITTLE ROCK    AR  (501) 376-4781
# 4               ROBINSON CENTER  LITTLE ROCK    AR  (501) 370-3246
#
#                 TYPE  ...             FORMERNM       YEARCHNG  FIXED_STS  \
# 0   MULTIUSE COMPLEX  ...        NOT AVAILABLE  NOT AVAILABLE          Y
# ...

# %%
client=pymongo.MongoClient("mongodb+srv://19pd12:Shreya_123@cluster0.oekib.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
df1=pd.read_csv("/content/convention.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0             X             Y  OBJECTID  CONV_ID  \
# 0           0 -9.603671e+06  3.816326e+06         1       62
# 1           1 -1.276142e+07  3.850495e+06         2      200
# 2           2 -1.024107e+07  4.058537e+06         3      125
# 3           3 -1.027150e+07  4.129777e+06         4      106
# 4           4 -1.027195e+07  4.129855e+06         5      113
#
#                            NAME         CITY STATE       TELEPHONE  \
# 0          THE GARRETT COLISEUM   MONTGOMERY    AL  (334) 356-6866
# 1             YUMA CIVIC CENTER         YUMA    AZ  (928) 373-5040
# 2  PINE BLUFF CONVENTION CENTER   PINE BLUFF    AR  (870) 536-7600
# 3  STATEHOUSE CONVENTION CENTER  LITTLE ROCK    AR  (501) 376-4781
# 4               ROBINSON CENTER  LITTLE ROCK    AR  (501) 370-3246
#
#                 TYPE  ...             FORMERNM       YEARCHNG  FIXED_STS  \
# 0   MULTIUSE COMPLEX  ...        NOT AVAILABLE  NOT AVAILABLE          Y
# ...

# %%
data=df1.to_dict(orient='records')

# %%
db=client['ZeroDown1_convention']

# %%
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017', 'cluster0-shard-00-02.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDown1_convention')

# %%
#db.df1.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-31-95a2491fc3e3> in <module>()
# ----> 1 db.df1.insert_many(data)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     613         blk = _Bulk(self, ordered, bypass_document_validation)
#     614         blk.ops = [doc for doc in gen()]
# --> 615         blk.execute(write_concern, session=session)
#     616         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     617
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     457                 self.execute_no_results(sock_info, generator)
#     458         else:
# --> 459             return self.execute_command(generator, write_concern, session)
#
# ...

# %%
client.list_database_names()
# Out:
# ['ZeroDown1_convention',
#  'ZeroDown1_sports',
#  'h3',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
data_sports= client.ZeroDown1_convention

# %%
res_db = data_sports.df1

# %%
res_db
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017', 'cluster0-shard-00-02.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDown1_convention'), 'df1')

# %% [markdown]
# # Data

# %%
for i in res_db.find():
  pprint(i)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'YEARCHNG': 'NOT AVAILABLE',
#  '_id': ObjectId('62483707b712cdca81f28421')}
# {'BALLROOM': 'N',
#  'CITY': 'JEFFERSON',
#  'COMPLEXNM': 'JEFFERSON COUNTY FAIRGROUNDS',
#  'CONV_ID': 4792,
#  'COUNTRY': 'USA',
#  'COUNTY': 'JEFFERSON',
#  'COUNTYFIPS': 55055,
#  'EXHIBIT': 'Y',
#  'FIXED_STS': 'N',
#  'FORMERNM': 'NOT AVAILABLE',
#  'LATITUDE': 43.0130142767663,
#  'LOBBY': 'N',
#  'LONGITUDE': -88.8197209766846,
#  'MAIN_FLOOR': 'N',
#  'MEET_ROOMS': 'N',
#  'NAICS_CODE': 561920,
#  'NAICS_DESC': 'CONVENTION AND TRADE SHOW ORGANIZERS',
#  'NAME': 'ACTIVITY CENTER',
#  'OBJECTID': 4873,
#  'OUTDOOR': 'N',
#  'PRE_FUNCT': 'N',
#  'SOURCE': 'https://www.jcfairpark.com/',
#  'SOURCEDATE': '2019/11/13 00:00:00+00',
#  'STATE': 'WI',
#  'STATUS': 'OPEN',
#  'TELEPHONE': '(920) 674-7148',
#  'TYPE': 'MULTIUSE COMPLEX',
#  'Unnamed: 0': 4872,
#  'VAL_DATE': '2019/11/13 00:00:00+00',
# ...

# %% [markdown]
# # Query

# %%
m1=df1['LATITUDE'].max()
n1=df1['LATITUDE'].min()

# %%
m2=df1['LONGITUDE'].max()
n2=df1['LONGITUDE'].min()

# %%
print(n1,"<=Latitude<=",m1)
x=float(input(print("Enter Latitude value of your choice")))
while(n1>x or x>m1):
  x=float(input("Enter valid value"))
print(n2,"<=Longitude<=",m2)
y=float(input(print("Enter Longitude value of your choice")))
while(n2>y or y>m2):
  y=float(input("Enter valid value"))
# Out:
# 17.9748342523989 <=Latitude<= 64.8668101706007
# Enter Latitude value of your choice
# 18.90
# -157.870585347407 <=Longitude<= -66.0922174783539
# Enter Longitude value of your choice
# -98.78

# %%
for i in res_db.find({'LATITUDE':{'$gt':n1 , '$lt':x}}):
    if(i['LONGITUDE']>n2 and i['LONGITUDE']<y):
      print("\n")
      pprint(i) 
    # Using urlopen() function with url in it  
      pprint('----------------------------------------------------------------------------------------------------------------')
      print("For more details about the place click on the link below")
      pprint(i['SOURCE'])
