# %%
# !pip install geopandas
# !pip install plotly
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 51.5 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 41.2 MB/s
# ...

# %%
import pymongo
from pymongo import MongoClient
import pprint
import datetime

# %%
import pandas as pd

# %%
import geopandas  as gpd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/zero/Convention_Centers_Fairgrounds.csv')

# %%
data.head()
# Out:
#               X             Y  OBJECTID  CONV_ID  \
# 0 -9.603671e+06  3.816326e+06         1       62
# 1 -1.276142e+07  3.850495e+06         2      200
# 2 -1.024107e+07  4.058537e+06         3      125
# 3 -1.027150e+07  4.129777e+06         4      106
# 4 -1.027195e+07  4.129855e+06         5      113
#
#                            NAME                       ADDRESS         CITY  \
# 0          THE GARRETT COLISEUM            1555 FEDERAL DRIVE   MONTGOMERY
# 1             YUMA CIVIC CENTER  1440 WEST DESERT HILLS DRIVE         YUMA
# 2  PINE BLUFF CONVENTION CENTER     1 CONVENTION CENTER PLAZA   PINE BLUFF
# 3  STATEHOUSE CONVENTION CENTER           101 S SPRING STREET  LITTLE ROCK
# 4               ROBINSON CENTER       426 WEST MARKHAM STREET  LITTLE ROCK
#
#   STATE    ZIP           ZIP4  ...             FORMERNM       YEARCHNG  \
# 0    AL  36107  NOT AVAILABLE  ...        NOT AVAILABLE  NOT AVAILABLE
# 1    AZ  85365  NOT AVAILABLE  ...        NOT AVAILABLE  NOT AVAILABLE
# ...

# %%
data['COMPLEXNM'].unique()
# Out:
# array(['THE ALABAMA AGRICULTURAL CENTER', 'NOT APPLICABLE',
#        'FRESNO CONVENTION AND ENTERTAINMENT CENTER',
#        'FAIRPLEX POMONA CALIFORNIA', 'PASADENA CONVENTION CENTER',
#        'SAFE CREDIT UNION CONVENTION AND PERFORMING ARTS DISTRICT',
#        'CAL EXPO', 'FLORIDA STATE FAIRGROUNDS',
#        'ORANGE COUNTY CONVENTION CENTER', 'GEORGIA WORLD CONGRESS CENTER',
#        'ATLANTA EXPO CENTERS', 'GWINNETT CENTER',
#        'LAMAR DIXON EXPO CENTER', 'ONCENTER COMPLEX', 'EXPO SQUARE',
#        'LANE EVENTS CENTER', 'LINN COUNTY EXPO CENTER',
#        'TRAVIS COUNTY EXPOSITION CENTER',
#        'THE NATIONAL CONFERENCE CENTER', 'THREE RIVERS CAMPUS',
#        'CLARK COUNTY EVENT CENTER AT THE FAIRGROUNDS',
#        'BIRMINGHAM-JEFFERSON CONVENTION COMPLEX', 'VON BRAUN CENTER',
#        'MESA CONVENTION CENTER', 'PHOENIX CONVENTION CENTER',
#        'ARIZONA EXPOSITION AND STATE FAIRGROUNDS',
#        'OC FAIR AND EVENT CENTER', 'SAN MATEO EVENT CENTER', 'COW PALACE',
# ...

# %%
data.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'CONV_ID', 'NAME', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'COUNTY', 'COUNTYFIPS',
#        'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC',
#        'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE',
#        'COMPLEXNM', 'FORMERNM', 'YEARCHNG', 'FIXED_STS', 'BALLROOM', 'EXHIBIT',
#        'LOBBY', 'MAIN_FLOOR', 'OUTDOOR', 'PRE_FUNCT', 'MEET_ROOMS'],
#       dtype='object')

# %%
data.drop(columns = ['ADDRESS','ZIP4','ZIP','VAL_METHOD'],inplace =True)

# %%
#DataCleaning
#1.checking for null values in the first column
data=data.dropna(axis=0)
r,c=data.shape
print(r,c)
data.isnull()
# Out:
# 5019 32
#           X      Y  OBJECTID  CONV_ID   NAME   CITY  STATE  TELEPHONE   TYPE  \
# 0     False  False     False    False  False  False  False      False  False
# 1     False  False     False    False  False  False  False      False  False
# 2     False  False     False    False  False  False  False      False  False
# 3     False  False     False    False  False  False  False      False  False
# 4     False  False     False    False  False  False  False      False  False
# ...     ...    ...       ...      ...    ...    ...    ...        ...    ...
# 5014  False  False     False    False  False  False  False      False  False
# 5015  False  False     False    False  False  False  False      False  False
# 5016  False  False     False    False  False  False  False      False  False
# 5017  False  False     False    False  False  False  False      False  False
# 5018  False  False     False    False  False  False  False      False  False
#
# ...

# %%
import numpy as np

# %%
#checking for percentage of null values in each column
for col in data.columns:
    pct_missing = np.mean(data[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# X - 0%
# Y - 0%
# OBJECTID - 0%
# CONV_ID - 0%
# NAME - 0%
# CITY - 0%
# STATE - 0%
# TELEPHONE - 0%
# TYPE - 0%
# STATUS - 0%
# COUNTY - 0%
# COUNTYFIPS - 0%
# COUNTRY - 0%
# LATITUDE - 0%
# LONGITUDE - 0%
# NAICS_CODE - 0%
# NAICS_DESC - 0%
# SOURCE - 0%
# SOURCEDATE - 0%
# VAL_DATE - 0%
# WEBSITE - 0%
# COMPLEXNM - 0%
# FORMERNM - 0%
# YEARCHNG - 0%
# FIXED_STS - 0%
# BALLROOM - 0%
# EXHIBIT - 0%
# LOBBY - 0%
# MAIN_FLOOR - 0%
# OUTDOOR - 0%
# PRE_FUNCT - 0%
# MEET_ROOMS - 0%

# %%
data.to_csv('convention.csv')
