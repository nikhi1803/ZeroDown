# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.1.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.21)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.5)

# %%
# !pip install dnspython
# Out:
# Collecting dnspython
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      |████████████████████████████████| 269 kB 10.4 MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-2.2.1

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (4.0.2)

# %%
import pymongo
import json
import pandas as pd
from pprint import pprint

# %%
data=pd.read_csv('/content/sports.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  OBJECTID  VENUEID                       NAME  \
# 0           0         1      1.0             MILWAUKEE MILE
# 1           1         2     16.0  STREETS OF ST. PETERSBURG
# 2           2         3     17.0      STREETS OF LONG BEACH
# 3           3         4     18.0    BARBER MOTORSPORTS PARK
# 4           4         5     20.0         STREETS OF TORONTO
#
#                        ADDRESS              CITY STATE      ZIP  \
# 0        640 SOUTH 84TH STREET        WEST ALLIS    WI    53214
# 1            BAYSHORE DRIVE SE  SAINT PETERSBURG    FL    33701
# 2     300 EAST OCEAN BOULEVARD        LONG BEACH    CA    90802
# 3  6040 BARBER MOTORSPORTS PKY        BIRMINGHAM    AL    35094
# 4       100 PRINCES' BOULEVARD           TORONTO    ON  M6K 3C3
#
#             ZIP4        TYPE  ... COUNTRY   LATITUDE   LONGITUDE  NAICS_CODE  \
# 0  NOT AVAILABLE  SINGLE USE  ...     USA  43.020180  -88.010630      711212
# 1  NOT AVAILABLE  SINGLE USE  ...     USA  27.765490  -82.629920      711212
# 2  NOT AVAILABLE  SINGLE USE  ...     USA  33.763232 -118.192625      711212
# 3  NOT AVAILABLE  SINGLE USE  ...     USA  33.532000  -86.619000      711212
# 4  NOT AVAILABLE  SINGLE USE  ...     CAN  43.633330  -79.415830      711212
#
#    NAICS_DESC                                             SOURCE  SOURCEDATE  \
# 0  RACETRACKS  http://wistatefair.com/wsfp/2018/01/22/milwauk...  2015-01-30
# 1  RACETRACKS                           http://www.gpstpete.com/  2015-01-30
# 2  RACETRACKS                               http://www.gplb.com/  2015-01-30
# 3  RACETRACKS                    https://barberracingevents.com/  2015-01-30
# 4  RACETRACKS                              http://hondaindy.com/  2015-01-30
#
#      VAL_DATE                         NAME2  \
# 0  2018-08-13                 NOT AVAILABLE
# 1  2018-08-13  GRAND PRIX OF ST. PETERSBURG
# 2  2018-08-13      GRAND PRIX OF LONG BEACH
# 3  2018-08-13         GRAND PRIX OF ALABAMA
# 4  2018-08-13                  INDY TORONTO
#
#                                     geometry
# 0    POINT (-9797298.5082 5315043.943599999)
# 1   POINT (-9198320.6198 3219439.4778000005)
# 2  POINT (-13157142.7841 3997054.0565000027)
# 3     POINT (-9642382.973 3966132.843699999)
# 4         POINT (-8840529.7565 5408873.3895)
#
# [5 rows x 24 columns]

# %%
client=pymongo.MongoClient("mongodb+srv://19pd12:Shreya_123@cluster0.oekib.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
df=pd.read_csv("/content/sports.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  OBJECTID  VENUEID                       NAME  \
# 0           0         1      1.0             MILWAUKEE MILE
# 1           1         2     16.0  STREETS OF ST. PETERSBURG
# 2           2         3     17.0      STREETS OF LONG BEACH
# 3           3         4     18.0    BARBER MOTORSPORTS PARK
# 4           4         5     20.0         STREETS OF TORONTO
#
#                        ADDRESS              CITY STATE      ZIP  \
# 0        640 SOUTH 84TH STREET        WEST ALLIS    WI    53214
# 1            BAYSHORE DRIVE SE  SAINT PETERSBURG    FL    33701
# 2     300 EAST OCEAN BOULEVARD        LONG BEACH    CA    90802
# 3  6040 BARBER MOTORSPORTS PKY        BIRMINGHAM    AL    35094
# 4       100 PRINCES' BOULEVARD           TORONTO    ON  M6K 3C3
#
#             ZIP4        TYPE  ... COUNTRY   LATITUDE   LONGITUDE  NAICS_CODE  \
# 0  NOT AVAILABLE  SINGLE USE  ...     USA  43.020180  -88.010630      711212
# 1  NOT AVAILABLE  SINGLE USE  ...     USA  27.765490  -82.629920      711212
# 2  NOT AVAILABLE  SINGLE USE  ...     USA  33.763232 -118.192625      711212
# 3  NOT AVAILABLE  SINGLE USE  ...     USA  33.532000  -86.619000      711212
# 4  NOT AVAILABLE  SINGLE USE  ...     CAN  43.633330  -79.415830      711212
#
#    NAICS_DESC                                             SOURCE  SOURCEDATE  \
# 0  RACETRACKS  http://wistatefair.com/wsfp/2018/01/22/milwauk...  2015-01-30
# 1  RACETRACKS                           http://www.gpstpete.com/  2015-01-30
# 2  RACETRACKS                               http://www.gplb.com/  2015-01-30
# 3  RACETRACKS                    https://barberracingevents.com/  2015-01-30
# 4  RACETRACKS                              http://hondaindy.com/  2015-01-30
#
#      VAL_DATE                         NAME2  \
# 0  2018-08-13                 NOT AVAILABLE
# 1  2018-08-13  GRAND PRIX OF ST. PETERSBURG
# 2  2018-08-13      GRAND PRIX OF LONG BEACH
# 3  2018-08-13         GRAND PRIX OF ALABAMA
# 4  2018-08-13                  INDY TORONTO
#
#                                     geometry
# 0    POINT (-9797298.5082 5315043.943599999)
# 1   POINT (-9198320.6198 3219439.4778000005)
# 2  POINT (-13157142.7841 3997054.0565000027)
# 3     POINT (-9642382.973 3966132.843699999)
# 4         POINT (-8840529.7565 5408873.3895)
#
# [5 rows x 24 columns]

# %%
data=df.to_dict(orient='records')

# %%
db=client['ZeroDown1_sports']

# %%
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-02.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDown1_sports')

# %%
db.df.insert_many(data)

# %%
client.list_database_names()
# Out:
# ['ZeroDown1_sports',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
data_sports= client.ZeroDown1_sports

# %%
res_db = data_sports.df

# %%
res_db
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-02.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDown1_sports'), 'df')

# %% [markdown]
# # Data

# %%
for i in res_db.find():
  pprint(i)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'Unnamed: 0': 629,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1145.0,
#  'ZIP': '76201',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472b9'),
#  'geometry': 'POINT (-10815159.4139 3923027.632799998)'}
# {'ADDRESS': '5000 VETERANS STADIUM DRIVE',
#  'CITY': 'TROY',
#  'COUNTRY': 'USA',
#  'COUNTY': 'PIKE',
#  'COUNTYFIPS': 28113,
#  'LATITUDE': 31.802211002000035,
#  'LONGITUDE': -85.95231379399996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'TROJAN ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 637,
#  'POPULATION': 5200.0,
#  'SOURCE': 'http://troytrojans.com/sports/2013/12/4/MBB_1204135846.aspx?id=316',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'AL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 630,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1146.0,
#  'ZIP': '36082',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ba'),
#  'geometry': 'POINT (-9568167.8041 3737375.658200003)'}
# {'ADDRESS': 'SUNFLOWER LANE AND LEFLORE AVENUE',
#  'CITY': 'ITTA BENA',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LEFLORE',
#  'COUNTYFIPS': 28083,
#  'LATITUDE': 33.51051254300006,
#  'LONGITUDE': -90.34104164699994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'HARRISON HPER COMPLEX',
#  'NAME2': 'RICHARD W. HARRISON HPER COMPLEX',
#  'OBJECTID': 639,
#  'POPULATION': 5000.0,
#  'SOURCE': 'https://mvsusports.com/news/2013/5/24/MBB_0524133541.aspx?path=mbball',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'MS',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 631,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1148.0,
#  'ZIP': '38941',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472bb'),
#  'geometry': 'POINT (-10056718.7539 3963263.6733999997)'}
# {'ADDRESS': 'L. W. MINOR STREET',
#  'CITY': 'PRAIRIE VIEW',
#  'COUNTRY': 'USA',
#  'COUNTY': 'WALLER',
#  'COUNTYFIPS': 48473,
#  'LATITUDE': 30.09228022300005,
#  'LONGITUDE': -95.99304932699994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'WILLIIAM NICKS BUILDING',
#  'NAME2': 'WILLIAM "BILLY" J. NICKS BUILDING',
#  'OBJECTID': 640,
#  'POPULATION': 6500.0,
#  'SOURCE': 'https://pvpanthers.com/sports/2014/7/30/MBB_0730141952.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 632,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1149.0,
#  'ZIP': '77445',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472bc'),
#  'geometry': 'POINT (-10685897.3708 3515417.1292999983)'}
# {'ADDRESS': 'INTERNATIONAL MALL AND PAYNE STREET',
#  'CITY': 'LAS CRUCES',
#  'COUNTRY': 'USA',
#  'COUNTY': 'DONA ANA',
#  'COUNTYFIPS': 35013,
#  'LATITUDE': 32.28401548100004,
#  'LONGITUDE': -106.74222554199996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'PAN AMERICAN CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 641,
#  'POPULATION': 12482.0,
#  'SOURCE': 'http://panam.nmsu.edu/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NM',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 633,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1150.0,
#  'ZIP': '88003',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472bd'),
#  'geometry': 'POINT (-11882490.193500001 3800650.0845)'}
# {'ADDRESS': 'WEST ALABAMA AVENUE AND PENNY LANE',
#  'CITY': 'RUSTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LINCOLN',
#  'COUNTYFIPS': 32017,
#  'LATITUDE': 32.53205307300004,
#  'LONGITUDE': -92.658551634,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'THOMAS ASSEMBLY CENTER',
#  'NAME2': 'SAMUEL M. THOMAS ASSEMBLY CENTER',
#  'OBJECTID': 642,
#  'POPULATION': 8000.0,
#  'SOURCE': 'https://latechsports.com/facilities/?id=2',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'LA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 634,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1151.0,
#  'ZIP': '71270',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472be'),
#  'geometry': 'POINT (-10314702.7855 3833355.2861)'}
# {'ADDRESS': '2650 E SHAW AVE',
#  'CITY': 'FRESNO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'FRESNO',
#  'COUNTYFIPS': 6019,
#  'LATITUDE': 36.80968310800006,
#  'LONGITUDE': -119.73846678999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'SAVE MART CENTER',
#  'NAME2': 'SAVE MART CENTER AT FRESNO STATE',
#  'OBJECTID': 643,
#  'POPULATION': 15596.0,
#  'SOURCE': 'http://savemartcenter.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 635,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1152.0,
#  'ZIP': '93710',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472bf'),
#  'geometry': 'POINT (-13329225.1514 4412612.1630000025)'}
# {'ADDRESS': 'LOWER CAMPUS ROAD',
#  'CITY': 'HONOLULU',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HONOLULU',
#  'COUNTYFIPS': 15003,
#  'LATITUDE': 21.294290000000046,
#  'LONGITUDE': -157.81887999999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'STAN SHERIFF CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 644,
#  'POPULATION': 10300.0,
#  'SOURCE': 'https://hawaiiathletics.com/sports/2008/5/14/stan_sheriff_center.aspx?tab=stansheriffcenter',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'HI',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 636,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1153.0,
#  'ZIP': '96822',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c0'),
#  'geometry': 'POINT (-17568317.3592 2427004.3198000006)'}
# {'ADDRESS': '1 SOUTHEAST MARTIN LUTHER KING JR BOULEVARD',
#  'CITY': 'EVANSVILLE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'VANDERBURGH',
#  'COUNTYFIPS': 18163,
#  'LATITUDE': 37.972150000000056,
#  'LONGITUDE': -87.56781999999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'FORD CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 645,
#  'POPULATION': 11000.0,
#  'SOURCE': 'http://fordcenter.com/home/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'IN',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 637,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1154.0,
#  'ZIP': '47708',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c1'),
#  'geometry': 'POINT (-9748005.1323 4575492.288599998)'}
# {'ADDRESS': '400 CEDAR AVENUE',
#  'CITY': 'WEST LONG BRANCH',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MONMOUTH',
#  'COUNTYFIPS': 34025,
#  'LATITUDE': 40.279469910000046,
#  'LONGITUDE': -74.00754518899998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'OCEANFIRST BANK CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 646,
#  'POPULATION': 4100.0,
#  'SOURCE': 'https://www.monmouth.edu/campus-planning/the-oceanfirst-bank-center/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NJ',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 638,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1155.0,
#  'ZIP': '07764',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c2'),
#  'geometry': 'POINT (-8238482.2453000005 4906637.5836)'}
# {'ADDRESS': '1390 VILLARD ST',
#  'CITY': 'EUGENE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LANE',
#  'COUNTYFIPS': 41039,
#  'LATITUDE': 44.04490000000004,
#  'LONGITUDE': -123.06620999999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'MATTHEW KNIGHT ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 647,
#  'POPULATION': 12369.0,
#  'SOURCE': 'http://matthewknightarena.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'OR',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 639,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1156.0,
#  'ZIP': '97401',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c3'),
#  'geometry': 'POINT (-13699667.8311 5472393.192900002)'}
# {'ADDRESS': '600 SOUTH PECAN STREET',
#  'CITY': 'ARLINGTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'TARRANT',
#  'COUNTYFIPS': 48439,
#  'LATITUDE': 32.73054000000008,
#  'LONGITUDE': -97.10808999999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'COLLEGE PARK CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 648,
#  'POPULATION': 7000.0,
#  'SOURCE': 'https://www.utacollegepark.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'MULTIUSE',
#  'Unnamed: 0': 640,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1157.0,
#  'ZIP': '76010',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c4'),
#  'geometry': 'POINT (-10810023.1307 3859592.0305999964)'}
# {'ADDRESS': '10501 FGCU BOULEVARD',
#  'CITY': 'FORT MEYERS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LEE',
#  'COUNTYFIPS': 48287,
#  'LATITUDE': 26.47106184300003,
#  'LONGITUDE': -81.76464294899995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ALICO ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 649,
#  'POPULATION': 4500.0,
#  'SOURCE': 'https://fgcuathletics.com/sports/2014/8/16/alicoarena.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'FL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 641,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1158.0,
#  'ZIP': '33965',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c5'),
#  'geometry': 'POINT (-9101998.418 3057541.9195999987)'}
# {'ADDRESS': 'HODGE DRIVE',
#  'CITY': 'SPARTANBURG',
#  'COUNTRY': 'USA',
#  'COUNTY': 'SPARTANBURG',
#  'COUNTYFIPS': 45083,
#  'LATITUDE': 34.99570797100006,
#  'LONGITUDE': -81.96886631399997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'G.B. HODGE CENTER',
#  'NAME2': 'HODGE CENTER',
#  'OBJECTID': 650,
#  'POPULATION': 837.0,
#  'SOURCE': 'https://www.upstatespartans.com/facilities/Hodge',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'SC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 642,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1159.0,
#  'ZIP': '29303',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c6'),
#  'geometry': 'POINT (-9124732.459 4163297.889799997)'}
# {'ADDRESS': '3601 SOUTH BROAD STREET',
#  'CITY': 'PHILADELPHIA',
#  'COUNTRY': 'USA',
#  'COUNTY': 'PHILADELPHIA',
#  'COUNTYFIPS': 42101,
#  'LATITUDE': 39.90116035700004,
#  'LONGITUDE': -75.17185877299994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'WELLS FARGO CENTER',
#  'NAME2': 'SPECTRUM II',
#  'OBJECTID': 651,
#  'POPULATION': 20456.0,
#  'SOURCE': 'https://www.wellsfargocenterphilly.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'PA',
#  'STATUS': 'OPEN',
#  'TYPE': 'MULTIUSE',
#  'Unnamed: 0': 643,
#  'VAL_DATE': '2019-01-06',
#  'VENUEID': 372.0,
#  'ZIP': '19148',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c7'),
#  'geometry': 'POINT (-8368093.0406 4851589.5502)'}
# {'ADDRESS': '550 MEMORIAL DRIVE',
#  'CITY': 'POCATELLO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BANNOCK',
#  'COUNTYFIPS': 16005,
#  'LATITUDE': 42.86999125900008,
#  'LONGITUDE': -112.42861553499996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'HOLT ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 652,
#  'POPULATION': 8000.0,
#  'SOURCE': 'https://isubengals.com/sports/2010/10/11/GEN_1011102301.aspx?path=general',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'ID',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 644,
#  'VAL_DATE': '2018-09-27',
#  'VENUEID': 1162.0,
#  'ZIP': '83201',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c8'),
#  'geometry': 'POINT (-12515496.2319 5292204.0803999975)'}
# {'ADDRESS': 'ASHLAND STREET',
#  'CITY': 'CLINTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LAURENS',
#  'COUNTYFIPS': 45059,
#  'LATITUDE': 34.46512849000004,
#  'LONGITUDE': -81.86895716999999,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'TEMPLETON PHYSICAL EDUCATION CENTER',
#  'NAME2': 'FURMAN PINSON ARENA',
#  'OBJECTID': 653,
#  'POPULATION': 2300.0,
#  'SOURCE': 'http://www.gobluehose.com/ViewArticle.dbml?ATCLID=1151441',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'SC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 645,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1163.0,
#  'ZIP': '29325',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472c9'),
#  'geometry': 'POINT (-9113610.6239 4091429.728500001)'}
# {'ADDRESS': '227 CAMPUS DRIVE',
#  'CITY': 'ASHEVILLE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BUNCOMBE',
#  'COUNTYFIPS': 37021,
#  'LATITUDE': 35.61815807200003,
#  'LONGITUDE': -82.56887087299998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'KIMMEL ARENA',
#  'NAME2': 'WILMA M. SHERRILL CENTER',
#  'OBJECTID': 654,
#  'POPULATION': 3200.0,
#  'SOURCE': 'https://uncabulldogs.com/facilities/?id=6',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 646,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1164.0,
#  'ZIP': '28804',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ca'),
#  'geometry': 'POINT (-9191524.661 4248206.916500002)'}
# {'ADDRESS': 'HINTON DRIVE',
#  'CITY': 'HOUSTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HARRIS',
#  'COUNTYFIPS': 48201,
#  'LATITUDE': 29.69500000000005,
#  'LONGITUDE': -95.51690999999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'SHARP GYMNASIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 655,
#  'POPULATION': 1000.0,
#  'SOURCE': 'https://hbuhuskies.com/sports/2011/9/21/Facilities.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 647,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1165.0,
#  'ZIP': '77074',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472cb'),
#  'geometry': 'POINT (-10632893.7833 3464404.8756000027)'}
# {'ADDRESS': '1 RALPH ENGELSTAD DRIVE',
#  'CITY': 'GRANK FORKS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'GRAND FORKS',
#  'COUNTYFIPS': 38035,
#  'LATITUDE': 47.92764572300007,
#  'LONGITUDE': -97.072373713,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'BETTY ENGELSTAD SIOUX CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 656,
#  'POPULATION': 3300.0,
#  'SOURCE': 'http://www.theralph.com/the-ralph/the-betty',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'ND',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 648,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1166.0,
#  'ZIP': '58203',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472cc'),
#  'geometry': 'POINT (-10806047.2118 6094826.091300003)'}
# {'ADDRESS': '305 HARRISON STREET',
#  'CITY': 'SEATTLE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'KING',
#  'COUNTYFIPS': 53033,
#  'LATITUDE': 47.62209000000007,
#  'LONGITUDE': -122.35405999999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'KEYARENA',
#  'NAME2': 'KEYARENA AT SEATTLE CENTER',
#  'OBJECTID': 657,
#  'POPULATION': 17072.0,
#  'SOURCE': 'http://www.keyarena.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'WA',
#  'STATUS': 'CLOSED',
#  'TYPE': 'OTHER',
#  'Unnamed: 0': 649,
#  'VAL_DATE': '2019-01-06',
#  'VENUEID': 389.0,
#  'ZIP': '98109',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472cd'),
#  'geometry': 'POINT (-13620391.6557 6044212.781400003)'}
# {'ADDRESS': 'ROADRUNNER DRIVE',
#  'CITY': 'BAKERSFIELD',
#  'COUNTRY': 'USA',
#  'COUNTY': 'KERN',
#  'COUNTYFIPS': 6029,
#  'LATITUDE': 35.34760468700006,
#  'LONGITUDE': -119.10276373899995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ICARDO CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 658,
#  'POPULATION': 3800.0,
#  'SOURCE': 'https://gorunners.com/news/2006/10/8/639747.aspx',
#  'SOURCEDATE': '2016-02-11',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 650,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1168.0,
#  'ZIP': '93301',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ce'),
#  'geometry': 'POINT (-13258459.011500001 4211220.1439)'}
# {'ADDRESS': '1535 WOOSTER STREET',
#  'CITY': 'BOWLING GREEN',
#  'COUNTRY': 'USA',
#  'COUNTY': 'WOOD',
#  'COUNTYFIPS': 55141,
#  'LATITUDE': 41.375260000000026,
#  'LONGITUDE': -83.62638999999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'STROH CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 659,
#  'POPULATION': 4700.0,
#  'SOURCE': 'https://bgsufalcons.com/sports/2012/6/11/MBB_0611123748.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'OH',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 651,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1169.0,
#  'ZIP': '43042',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472cf'),
#  'geometry': 'POINT (-9309247.1517 5067850.994800001)'}
# {'ADDRESS': '1801 FAYETTEVILLE STREET',
#  'CITY': 'DURHAM',
#  'COUNTRY': 'USA',
#  'COUNTY': 'DURHAM',
#  'COUNTYFIPS': 37063,
#  'LATITUDE': 35.97583000000003,
#  'LONGITUDE': -78.89777999999995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'MCDOUGALD-MCLENDON GYMNASIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 660,
#  'POPULATION': 3116.0,
#  'SOURCE': 'https://nccueaglepride.com/sports/2010/6/11/MBB_0611103023.aspx?id=2',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 652,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1170.0,
#  'ZIP': '27707',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d0'),
#  'geometry': 'POINT (-8782860.6943 4297296.126800001)'}
# {'ADDRESS': '2523 GWYNNS FALLS PARKWAY',
#  'CITY': 'BALTIMORE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BALTIMORE (CITY)',
#  'COUNTYFIPS': 24510,
#  'LATITUDE': 39.315451395000025,
#  'LONGITUDE': -76.65744842599997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'PHYSICAL EDUCATION COMPLEX',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 661,
#  'POPULATION': 4100.0,
#  'SOURCE': 'https://coppinstatesports.com/sports/2015/6/2/GEN_0602153018.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'MD',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 653,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1171.0,
#  'ZIP': '21212',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d1'),
#  'geometry': 'POINT (-8533468.1243 4766958.536200002)'}
# {'ADDRESS': '1150 DOUGLAS PIKE',
#  'CITY': 'SMITHFIELD',
#  'COUNTRY': 'USA',
#  'COUNTY': 'PROVIDENCE',
#  'COUNTYFIPS': 44007,
#  'LATITUDE': 41.92125263100007,
#  'LONGITUDE': -71.53963404299998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'CHACE ATHLETIC CENTER',
#  'NAME2': 'ELIZABETH & MALCOLM CHACE WELLNESS & AC',
#  'OBJECTID': 662,
#  'POPULATION': 2600.0,
#  'SOURCE': 'https://www.bryantbulldogs.com/information/Facilities/Chace',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'RI',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 654,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1172.0,
#  'ZIP': '02917',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d2'),
#  'geometry': 'POINT (-7963755.633199999 5149190.759199999)'}
# {'ADDRESS': 'NORTH CIRCLE DRIVE AND NORTHWEST ROAD',
#  'CITY': 'EDWARDSVILLE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MADISON',
#  'COUNTYFIPS': 30057,
#  'LATITUDE': 38.79634149800006,
#  'LONGITUDE': -89.99992848799997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'VADALABENE CENTER',
#  'NAME2': 'SAM M. VADALABENE CENTER',
#  'OBJECTID': 663,
#  'POPULATION': 4000.0,
#  'SOURCE': 'https://www.siuecougars.com/facilities/vadalabene_center_basketball',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'IL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 655,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1173.0,
#  'ZIP': '62026',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d3'),
#  'geometry': 'POINT (-10018746.2107 4692541.082699999)'}
# {'ADDRESS': '250 BEARD-EAVES COURT',
#  'CITY': 'AUBURN',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LEE',
#  'COUNTYFIPS': 48287,
#  'LATITUDE': 32.602808768000045,
#  'LONGITUDE': -85.49248716999995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'AUBURN ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 664,
#  'POPULATION': 9121.0,
#  'SOURCE': 'https://auburntigers.com/facilities/?id=1',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'AL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 656,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1174.0,
#  'ZIP': '36830',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d4'),
#  'geometry': 'POINT (-9516980.1384 3842701.3664999977)'}
# {'ADDRESS': '301 MEETING ST',
#  'CITY': 'CHARLESTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'CHARLESTON',
#  'COUNTYFIPS': 45019,
#  'LATITUDE': 32.785431989000074,
#  'LONGITUDE': -79.93441869599997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'TD ARENA',
#  'NAME2': 'TORONTO DOMINION BANK ARENA',
#  'OBJECTID': 665,
#  'POPULATION': 5100.0,
#  'SOURCE': 'https://cofcsports.com/sports/2006/12/8/717604.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'SC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 657,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1175.0,
#  'ZIP': '29401',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d5'),
#  'geometry': 'POINT (-8898258.7861 3866858.158)'}
# {'ADDRESS': 'TAYLOR STREET',
#  'CITY': 'VERMILLION',
#  'COUNTRY': 'USA',
#  'COUNTY': 'CLAY',
#  'COUNTYFIPS': 19041,
#  'LATITUDE': 42.79114040200005,
#  'LONGITUDE': -96.927768981,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'DAKOTADOME',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 666,
#  'POPULATION': 10000.0,
#  'SOURCE': 'https://goyotes.com/facilities/?id=14',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'SD',
#  'STATUS': 'OPEN',
#  'TYPE': 'OTHER',
#  'Unnamed: 0': 658,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1176.0,
#  'ZIP': '57069',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d6'),
#  'geometry': 'POINT (-10789949.8867 5280235.126800001)'}
# {'ADDRESS': '1234 GRAMBLING ROAD',
#  'CITY': 'GRAMBLING',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LINCOLN',
#  'COUNTYFIPS': 32017,
#  'LATITUDE': 32.52036533200004,
#  'LONGITUDE': -92.72379584699996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'FREDRICK C. HOBDY ASSEMBLY CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 667,
#  'POPULATION': 7500.0,
#  'SOURCE': 'https://gsutigers.com/sports/2018/6/25/fredrick-c-hobdy-assembly-center.aspx?id=38',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'LA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 659,
#  'VAL_DATE': '2018-10-01',
#  'VENUEID': 1177.0,
#  'ZIP': '71245',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d7'),
#  'geometry': 'POINT (-10321965.7381 3831812.167800002)'}
# {'ADDRESS': '1621 VIRGINIA STREET',
#  'CITY': 'MOBILE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MOBILE',
#  'COUNTYFIPS': 1097,
#  'LATITUDE': 30.67306700000006,
#  'LONGITUDE': -88.07563499999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'LADD-PEEBLES STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 668,
#  'POPULATION': 33471.0,
#  'SOURCE': 'http://laddpeeblesstadium.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'AL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 660,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1178.0,
#  'ZIP': '36604',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d8'),
#  'geometry': 'POINT (-9804534.8395 3590363.0600000024)'}
# {'ADDRESS': '300 STADIUM DRIVE',
#  'CITY': 'HADLEY',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HAMPSHIRE',
#  'COUNTYFIPS': 25015,
#  'LATITUDE': 42.37739000000005,
#  'LONGITUDE': -72.53602499999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'WARREN MCGUIRK ALUMNI STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 669,
#  'POPULATION': 17000.0,
#  'SOURCE': 'https://umassathletics.com/sports/2016/7/1/school-bio-facilities-html.aspx#mcguirk',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'MA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 661,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1179.0,
#  'ZIP': '01003',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472d9'),
#  'geometry': 'POINT (-8074673.3672 5217679.347900003)'}
# {'ADDRESS': '1100 AQUARENA SPRINGS DRIVE',
#  'CITY': 'SAN MARCOS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HAYS',
#  'COUNTYFIPS': 65600,
#  'LATITUDE': 29.89106144600004,
#  'LONGITUDE': -97.925541518,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'JIM WACKER FIELD AT BOBCAT STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 670,
#  'POPULATION': 30000.0,
#  'SOURCE': 'https://txstatebobcats.com/sports/2010/7/29/FB_0729105705.aspx?tab=jimwackerfieldatbobcatstadium',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 662,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1180.0,
#  'ZIP': '78666',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472da'),
#  'geometry': 'POINT (-10901021.4174 3489554.4799000025)'}
# {'ADDRESS': '100 MONTANA STREET',
#  'CITY': 'SAN ANTONIO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BEXAR',
#  'COUNTYFIPS': 48029,
#  'LATITUDE': 29.41690221400006,
#  'LONGITUDE': -98.47898242799994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ALAMODOME',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 671,
#  'POPULATION': 65000.0,
#  'SOURCE': 'http://www.alamodome.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 663,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1181.0,
#  'ZIP': '78203',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472db'),
#  'geometry': 'POINT (-10962630.1777 3428816.1130999997)'}
# {'ADDRESS': '270 STADIUM DRIVE',
#  'CITY': 'BOONE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'WATAUGA',
#  'COUNTYFIPS': 37189,
#  'LATITUDE': 36.211605949000045,
#  'LONGITUDE': -81.68554871599997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'KIDD BREWER STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 672,
#  'POPULATION': 30000.0,
#  'SOURCE': 'https://appstatesports.com/news/2015/8/1/204989181.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 664,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1182.0,
#  'ZIP': '28607',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472dc'),
#  'geometry': 'POINT (-9093193.6882 4329777.224799998)'}
# {'ADDRESS': '5115 HAMPTON BOULEVARD',
#  'CITY': 'NORFOLK',
#  'COUNTRY': 'USA',
#  'COUNTY': 'NORFOLK',
#  'COUNTYFIPS': 51710,
#  'LATITUDE': 36.88891917800004,
#  'LONGITUDE': -76.30488910299994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'FOREMAN FIELD AT S. B. BALLARD STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 673,
#  'POPULATION': 20118.0,
#  'SOURCE': 'http://www.odusports.com/ViewArticle.dbml?ATCLID=208427122',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'VA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 665,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1183.0,
#  'ZIP': '23529',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472dd'),
#  'geometry': 'POINT (-8494221.4 4423634.842500001)'}
# {'ADDRESS': '207 LANIER DRIVE',
#  'CITY': 'STATESBORO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BULLOCH',
#  'COUNTYFIPS': 13031,
#  'LATITUDE': 32.41216600000007,
#  'LONGITUDE': -81.78314499999999,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'PAULSON STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 674,
#  'POPULATION': 25000.0,
#  'SOURCE': 'https://gseagles.com/sports/2013/7/23/FB_0723131314.aspx?id=16',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'GA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 666,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1184.0,
#  'ZIP': '30458',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472de'),
#  'geometry': 'POINT (-9104058.0569 3817536.2537999973)'}
# {'ADDRESS': '8701 PHILLIPS RD',
#  'CITY': 'CHARLOTTE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MECKLENBURG',
#  'COUNTYFIPS': 37119,
#  'LATITUDE': 35.31051100000008,
#  'LONGITUDE': -80.74012499999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'JERRY RICHARDSON STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 675,
#  'POPULATION': 15314.0,
#  'SOURCE': 'https://charlotte49ers.com/sports/2016/7/25/welcome-to-jerry-richardson-stadium.aspx?id=1666',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 667,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1185.0,
#  'ZIP': '28262',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472df'),
#  'geometry': 'POINT (-8987949.6016 4206158.822899997)'}
# {'ADDRESS': '4750 RUE SHERBROOKE EST',
#  'CITY': 'MONTREAL',
#  'COUNTRY': 'CAN',
#  'COUNTY': 'MONTREAL',
#  'COUNTYFIPS': 2466025,
#  'LATITUDE': 45.56309305100007,
#  'LONGITUDE': -73.55265341099994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'SAPUTO STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 676,
#  'POPULATION': 20801.0,
#  'SOURCE': 'https://www.impactmontreal.com/fr/stadium/stade-saputo',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'QC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 668,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1186.0,
#  'ZIP': 'H1V 1A1',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e0'),
#  'geometry': 'POINT (-8187843.9242 5710608.888700001)'}
# {'ADDRESS': '1 CITRUS BOWL PLACE',
#  'CITY': 'ORLANDO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ORANGE',
#  'COUNTYFIPS': 12095,
#  'LATITUDE': 28.53904164100004,
#  'LONGITUDE': -81.40277138399995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'CAMPING WORLD STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 677,
#  'POPULATION': 65438.0,
#  'SOURCE': 'http://www.campingworldstadium.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'FL',
#  'STATUS': 'OPEN',
#  'TYPE': 'OTHER',
#  'Unnamed: 0': 669,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1187.0,
#  'ZIP': '32801',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e1'),
#  'geometry': 'POINT (-9061715.0596 3317106.167800002)'}
# {'ADDRESS': '1 RELIANT PARK',
#  'CITY': 'HOUSTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HARRIS',
#  'COUNTYFIPS': 48201,
#  'LATITUDE': 29.68260000000004,
#  'LONGITUDE': -95.40799999999996,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'GRAND PRIX OF HOUSTON',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 678,
#  'POPULATION': -999.0,
#  'SOURCE': 'http://www.grandprixofhouston.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 670,
#  'VAL_DATE': '2019-01-06',
#  'VENUEID': 1188.0,
#  'ZIP': '77054',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e2'),
#  'geometry': 'POINT (-10620769.9776 3462815.930399999)'}
# {'ADDRESS': '2717 DELTA DOWNS DRIVE',
#  'CITY': 'VINTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'CALCASIEU',
#  'COUNTYFIPS': 22019,
#  'LATITUDE': 30.193150170000024,
#  'LONGITUDE': -93.62314738399994,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'DELTA DOWNS',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 679,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://www.deltadowns.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'LA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 671,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1189.0,
#  'ZIP': '70668',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e3'),
#  'geometry': 'POINT (-10422081.0933 3528401.7365999967)'}
# {'ADDRESS': '11225 RACE TRACK ROAD',
#  'CITY': 'TAMPA',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HILLSBOROUGH',
#  'COUNTYFIPS': 12057,
#  'LATITUDE': 28.05146000000008,
#  'LONGITUDE': -82.64599999999996,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'TAMPA BAY DOWNS',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 680,
#  'POPULATION': -999.0,
#  'SOURCE': 'http://www.tampabaydowns.com',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'FL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 672,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1190.0,
#  'ZIP': '33626',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e4'),
#  'geometry': 'POINT (-9200110.6361 3255463.2688000016)'}
# {'ADDRESS': '1200 FUTURITY DRIVE',
#  'CITY': 'SUNLAND PARK',
#  'COUNTRY': 'USA',
#  'COUNTY': 'DOÑA ANA',
#  'COUNTYFIPS': 35013,
#  'LATITUDE': 31.80705000000006,
#  'LONGITUDE': -106.55899999999995,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'SUNLAND PARK',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 681,
#  'POPULATION': -999.0,
#  'SOURCE': 'http://www.sunland-park.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NM',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 673,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1191.0,
#  'ZIP': '88063',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e5'),
#  'geometry': 'POINT (-11862093.6194 3738009.5050000027)'}
# {'ADDRESS': '7500 TURFWAY ROAD',
#  'CITY': 'FLORENCE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BOONE',
#  'COUNTYFIPS': 21015,
#  'LATITUDE': 39.02450200000004,
#  'LONGITUDE': -84.63476999999995,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'TURFWAY PARK',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 682,
#  'POPULATION': -999.0,
#  'SOURCE': 'http://www.turfway.com/home',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'KY',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 674,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1192.0,
#  'ZIP': '41042',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e6'),
#  'geometry': 'POINT (-9421499.4998 4725181.881800003)'}
# {'ADDRESS': 'KATELLA AVENUE',
#  'CITY': 'CYPRESS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ORANGE',
#  'COUNTYFIPS': 6059,
#  'LATITUDE': 33.80875000000003,
#  'LONGITUDE': -118.04369999999994,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'LOS ALAMITOS',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 683,
#  'POPULATION': -999.0,
#  'SOURCE': 'http://www.losalamitos.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 675,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1193.0,
#  'ZIP': '90720',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e7'),
#  'geometry': 'POINT (-13140564.5754 4003150.641999997)'}
# {'ADDRESS': '620 ATLANTIC AVENUE',
#  'CITY': 'BROOKLYN',
#  'COUNTRY': 'USA',
#  'COUNTY': 'KINGS',
#  'COUNTYFIPS': 36047,
#  'LATITUDE': 40.68257325100007,
#  'LONGITUDE': -73.97523033899995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'BARCLAYS CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 684,
#  'POPULATION': 17732.0,
#  'SOURCE': 'https://www.barclayscenter.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'NY',
#  'STATUS': 'OPEN',
#  'TYPE': 'MULTIUSE',
#  'Unnamed: 0': 676,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1194.0,
#  'ZIP': '11217',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e8'),
#  'geometry': 'POINT (-8234884.9727 4965633.434900001)'}
# {'ADDRESS': '6801 FRANKLIN AVENUE',
#  'CITY': 'NEW ORLEANS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ORLEANS',
#  'COUNTYFIPS': 22071,
#  'LATITUDE': 30.030099937000045,
#  'LONGITUDE': -90.05064245399996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'LAKEFRONT ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 685,
#  'POPULATION': 8933.0,
#  'SOURCE': 'http://arena.uno.edu/default.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'LA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 677,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1195.0,
#  'ZIP': '70122',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472e9'),
#  'geometry': 'POINT (-10024391.6636 3507419.496799998)'}
# {'ADDRESS': '1600 CAMPUS COURT',
#  'CITY': 'ABILENE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'TAYLOR',
#  'COUNTYFIPS': 48441,
#  'LATITUDE': 32.47038855400007,
#  'LONGITUDE': -99.70921921399996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'MOODY COLISEUM (ACU)',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 686,
#  'POPULATION': 4600.0,
#  'SOURCE': 'https://acusports.com/sports/2009/6/29/moody_coliseum.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 678,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1196.0,
#  'ZIP': '79601',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ea'),
#  'geometry': 'POINT (-11099579.5103 3825216.0565000027)'}
# {'ADDRESS': '3300 WEST CAMELBACK ROAD',
#  'CITY': 'PHOENIX',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MARICOPA',
#  'COUNTYFIPS': 4013,
#  'LATITUDE': 33.51024270500005,
#  'LONGITUDE': -112.12894226699996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'GCU ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 687,
#  'POPULATION': 7000.0,
#  'SOURCE': 'http://www.gcuarena.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'AZ',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 679,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1197.0,
#  'ZIP': '85017',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472eb'),
#  'geometry': 'POINT (-12482136.7564 3963227.6471000016)'}
# {'ADDRESS': '4300 BROADWAY',
#  'CITY': 'SAN ANTONIO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BEXAR',
#  'COUNTYFIPS': 48029,
#  'LATITUDE': 29.468076205000045,
#  'LONGITUDE': -98.46933086999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'MCDERMOTT CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 688,
#  'POPULATION': 2000.0,
#  'SOURCE': 'https://uiwcardinals.com/sports/2009/7/2/GEN_0702095708.aspx?tab=facilities',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 680,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1198.0,
#  'ZIP': '78209',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ec'),
#  'geometry': 'POINT (-10961555.7712 3435357.614)'}
# {'ADDRESS': 'VFW HIGHWAY',
#  'CITY': 'LOWELL',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MIDDLESEX',
#  'COUNTYFIPS': 25017,
#  'LATITUDE': 42.65549968700003,
#  'LONGITUDE': -71.32414871599997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'COSTELLO ATHLETIC CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 689,
#  'POPULATION': 2000.0,
#  'SOURCE': 'https://goriverhawks.com/sports/2014/7/18/general_0718141622.aspx?id=178',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'MA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 681,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1199.0,
#  'ZIP': '01854',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ed'),
#  'geometry': 'POINT (-7939767.916300001 5259681.5286)'}
# {'ADDRESS': '2425 SOUTH 67TH STREET',
#  'CITY': 'OMAHA',
#  'COUNTRY': 'USA',
#  'COUNTY': 'DOUGLAS',
#  'COUNTYFIPS': 31055,
#  'LATITUDE': 41.23616500000003,
#  'LONGITUDE': -96.01302099999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'BAXTER ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 690,
#  'POPULATION': 7898.0,
#  'SOURCE': 'https://omavs.com/index.aspx?path=baxterarena',
#  'SOURCEDATE': '2016-02-08',
#  'STATE': 'NE',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 682,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1200.0,
#  'ZIP': '68106',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ee'),
#  'geometry': 'POINT (-10688120.6072 5047238.602899998)'}
# {'ADDRESS': '500 NUNN DRIVE',
#  'CITY': 'HIGHLAND HEIGHTS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'CAMPBELL',
#  'COUNTYFIPS': 21037,
#  'LATITUDE': 39.03193469400003,
#  'LONGITUDE': -84.45909715399995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'BB&T ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 691,
#  'POPULATION': 9400.0,
#  'SOURCE': 'http://www.thebbtarena.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'KY',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 683,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1201.0,
#  'ZIP': '41099',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472ef'),
#  'geometry': 'POINT (-9401943.688 4726246.976300001)'}
# {'ADDRESS': '2200 TEXAS AVENUE',
#  'CITY': 'HOUSTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HARRIS',
#  'COUNTYFIPS': 48201,
#  'LATITUDE': 29.75232500000004,
#  'LONGITUDE': -95.35205999999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'BBVA COMPASS STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 692,
#  'POPULATION': 22039.0,
#  'SOURCE': 'http://www.bbvacompassstadium.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 684,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1202.0,
#  'ZIP': '77003',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f0'),
#  'geometry': 'POINT (-10614542.7653 3471753.094300002)'}
# {'ADDRESS': 'SOUTH MARTIN LUTHER KING JR BLVD',
#  'CITY': 'WACO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MCLENNAN',
#  'COUNTYFIPS': 48309,
#  'LATITUDE': 31.55817800000005,
#  'LONGITUDE': -97.11567699999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'MCLANE STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 693,
#  'POPULATION': 45140.0,
#  'SOURCE': 'http://www.mclanestadium.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 685,
#  'VAL_DATE': '2019-01-06',
#  'VENUEID': 176.0,
#  'ZIP': '76704',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f1'),
#  'geometry': 'POINT (-10810867.7117 3705453.3329000026)'}
# {'ADDRESS': 'BEN WEINER DRIVE',
#  'CITY': 'NEW ORLEANS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ORLEANS',
#  'COUNTYFIPS': 22071,
#  'LATITUDE': 29.94460000000004,
#  'LONGITUDE': -90.116,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'YULMAN STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 694,
#  'POPULATION': 30000.0,
#  'SOURCE': 'https://tulanegreenwave.com/facilities/?id=30',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'LA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 686,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1203.0,
#  'ZIP': '70118',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f2'),
#  'geometry': 'POINT (-10031667.2323 3496430.6758999974)'}
# {'ADDRESS': '3874 HOLMAN STREET',
#  'CITY': 'HOUSTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HARRIS',
#  'COUNTYFIPS': 48201,
#  'LATITUDE': 29.72200000000004,
#  'LONGITUDE': -95.34919999999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'TDECU STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 695,
#  'POPULATION': 40000.0,
#  'SOURCE': 'https://uhcougars.com/sports/2018/6/12/TDECU-Stadium-Info-html.aspx',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 687,
#  'VAL_DATE': '2019-01-06',
#  'VENUEID': 403.0,
#  'ZIP': '77004',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f3'),
#  'geometry': 'POINT (-10614224.3915 3467865.3540999964)'}
# {'ADDRESS': '1600 ATLAS PEAK ROAD',
#  'CITY': 'NAPA',
#  'COUNTRY': 'USA',
#  'COUNTY': 'NAPA',
#  'COUNTYFIPS': 6055,
#  'LATITUDE': 38.34873745900006,
#  'LONGITUDE': -122.26426432899996,
#  'NAICS_CODE': 713910,
#  'NAICS_DESC': 'GOLF COURSES AND COUNTRY CLUBS',
#  'NAME': 'SILVERADO RESORT AND SPA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 696,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://www.silveradoresort.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 688,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1204.0,
#  'ZIP': '94558',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f4'),
#  'geometry': 'POINT (-13610395.647300001 4628808.5352)'}
# {'ADDRESS': '345 SAINT ANDREWS DRIVE',
#  'CITY': 'JACKSON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HINDS',
#  'COUNTYFIPS': 28049,
#  'LATITUDE': 32.39691783800004,
#  'LONGITUDE': -90.09864301299996,
#  'NAICS_CODE': 713910,
#  'NAICS_DESC': 'GOLF COURSES AND COUNTRY CLUBS',
#  'NAME': 'COUNTRY CLUB OF JACKSON',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 697,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://www.ccjackson.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'MS',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 689,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1205.0,
#  'ZIP': '39211',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f5'),
#  'geometry': 'POINT (-10029735.0614 3815525.775399998)'}
# {'ADDRESS': '99 HARDING ROAD',
#  'CITY': 'SAN FRANCISCO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'SAN FRANCISCO',
#  'COUNTYFIPS': 6075,
#  'LATITUDE': 37.72470144900007,
#  'LONGITUDE': -122.49371982399998,
#  'NAICS_CODE': 713910,
#  'NAICS_DESC': 'GOLF COURSES AND COUNTRY CLUBS',
#  'NAME': 'TOURNAMENT PLAYERS CLUB HARDING PARK',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 698,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://tpc.com/hardingpark/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 690,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1206.0,
#  'ZIP': '94132',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e15216472f6'),
#  'geometry': 'POINT (-13635938.5162 4540608.0264)'}
# {'ADDRESS': '6320 GRANDVIEW DRIVE WEST',
#  'CITY': 'UNIVERSITY PLACE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'PIERCE',
#  'COUNTYFIPS': 53053,
#  'LATITUDE': 47.200409689000026,
#  'LONGITUDE': -122.57068934699998,
#  'NAICS_CODE': 713910,
#  'NAICS_DESC': 'GOLF COURSES AND COUNTRY CLUBS',
#  'NAME': 'CHAMBERS BAY',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 699,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://www.chambersbaygolf.com/',
#  'SOURCEDATE': '2015-01-30',
#  'STATE': 'WA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 691,
#  'VAL_DATE': '2018-10-03',
#  'VENUEID': 1207.0,
#  'ZIP': '98467',
#  'ZIP4': 'NOT AVAILABLE',
# ...
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 818,
#  'POPULATION': 6000.0,
#  'SOURCE': 'http://www.tecolotes2laredos.com/uni-trade-stadium/',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 803,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1316.0,
#  'ZIP': '78041',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647367'),
#  'geometry': 'POINT (-11071302.3321 3192882.1037999988)'}
# {'ADDRESS': 'ENTRADA A LA CIUDAD DEPORTIVA',
#  'CITY': 'NUEVO LAREDO',
#  'COUNTRY': 'MEX',
#  'COUNTY': 'NUEVO LAREDO',
#  'COUNTYFIPS': 28027,
#  'LATITUDE': 27.48016000000007,
#  'LONGITUDE': -99.59201899999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ESTADIO NUEVO LAREDO',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 819,
#  'POPULATION': 7555.0,
#  'SOURCE': 'http://www.tecolotes2laredos.com/nuevo-laredo/',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'TM',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 804,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1317.0,
#  'ZIP': '88000',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647368'),
#  'geometry': 'POINT (-11086532.8422 3183590.546)'}
# {'ADDRESS': 'BULEVAR CONGRESO DE CHILPANCINGO 803',
#  'CITY': 'LEON',
#  'COUNTRY': 'MEX',
#  'COUNTY': 'LEON',
#  'COUNTYFIPS': 11020,
#  'LATITUDE': 21.145500000000027,
#  'LONGITUDE': -101.65953799999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ESTADIO DOMINGO SANTANA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 820,
#  'POPULATION': 8500.0,
#  'SOURCE': 'https://deportedigital.mx/presenta-remodelacion-del-parque-domingo-santana-avance-del-20-ciento',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'GT',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 805,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1318.0,
#  'ZIP': '37237',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647369'),
#  'geometry': 'POINT (-11316688.0044 2409236.3885999992)'}
# {'ADDRESS': '2101 E COLISEUM BLVD',
#  'CITY': 'FORT WAYNE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ALLEN',
#  'COUNTYFIPS': 18003,
#  'LATITUDE': 41.11968400000006,
#  'LONGITUDE': -85.10726999999997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'HILLIARD GATES SPORTS CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 821,
#  'POPULATION': 1800.0,
#  'SOURCE': 'https://gomastodons.com/facilities/?id=2',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'IN',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 806,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1319.0,
#  'ZIP': '46835',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164736a'),
#  'geometry': 'POINT (-9474097.9592 5030011.086599998)'}
# {'ADDRESS': '615 N PINE STREET',
#  'CITY': 'FLORENCE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LAUDERDALE',
#  'COUNTYFIPS': 1077,
#  'LATITUDE': 34.80840200000006,
#  'LONGITUDE': -87.68379299999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'FLOWERS HALL',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 822,
#  'POPULATION': 3500.0,
#  'SOURCE': 'http://una.sidearmsports.com/facilities/?id=3',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'AL',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 807,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1320.0,
#  'ZIP': '35630',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164736b'),
#  'geometry': 'POINT (-9760915.1876 4137874.128700003)'}
# {'ADDRESS': '8431 DIANA AVE',
#  'CITY': 'RIVERSIDE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'RIVERSIDE',
#  'COUNTYFIPS': 6065,
#  'LATITUDE': 33.92732625000008,
#  'LONGITUDE': -117.42304276799996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'CBU EVENTS CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 823,
#  'POPULATION': 5050.0,
#  'SOURCE': 'http://cbulancers.com/sports/2017/10/30/cbu-events-center.aspx',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 808,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1321.0,
#  'ZIP': '92504',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164736c'),
#  'geometry': 'POINT (-13071473.3283 4019047.8863999993)'}
# {'ADDRESS': '100 LOCK ST',
#  'CITY': 'NEWARK',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ESSEX',
#  'COUNTYFIPS': 34013,
#  'LATITUDE': 40.74230855400003,
#  'LONGITUDE': -74.18047932099995,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'WELLNESS AND EVENTS CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 824,
#  'POPULATION': 3500.0,
#  'SOURCE': 'https://www.njithighlanders.com/facilities/?id=129',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'NJ',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 809,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1322.0,
#  'ZIP': '07102',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164736d'),
#  'geometry': 'POINT (-8257733.184800001 4974406.215999998)'}
# {'ADDRESS': '901 VEL R PHILLIPS AVE',
#  'CITY': 'MILWAUKEE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MILWAUKEE',
#  'COUNTYFIPS': 55079,
#  'LATITUDE': 43.04505000000006,
#  'LONGITUDE': -87.91731799999997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'FISERV FORUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 825,
#  'POPULATION': 17000.0,
#  'SOURCE': 'https://www.fiservforum.com/',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'WI',
#  'STATUS': 'OPEN',
#  'TYPE': 'MULTIUSE',
#  'Unnamed: 0': 810,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1323.0,
#  'ZIP': '53203',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164736e'),
#  'geometry': 'POINT (-9786911.0717 5318831.432099998)'}
# {'ADDRESS': '198 CENTRAL AVENUE',
#  'CITY': 'WHITE PLAINS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'WESTCHESTER',
#  'COUNTYFIPS': 36119,
#  'LATITUDE': 41.03716500000007,
#  'LONGITUDE': -73.77889599999997,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'WESTCHESTER COUNTY CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 826,
#  'POPULATION': 5000.0,
#  'SOURCE': 'http://www.countycenter.biz/',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'NY',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 811,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1324.0,
#  'ZIP': '10606',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164736f'),
#  'geometry': 'POINT (-8213029.134 5017825.039300002)'}
# {'ADDRESS': '3950 S LAS VEGAS BLVD',
#  'CITY': 'LAS VEGAS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'CLARK',
#  'COUNTYFIPS': 32003,
#  'LATITUDE': 36.09065469200005,
#  'LONGITUDE': -115.17891454,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'MANDALAY BAY EVENTS CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 827,
#  'POPULATION': 12000.0,
#  'SOURCE': 'https://www.mandalaybay.com/en/entertainment/mandalay-bay-events-center.html',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'NV',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 812,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1325.0,
#  'ZIP': '89109',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647370'),
#  'geometry': 'POINT (-12821658.116700001 4313102.498300001)'}
# {'ADDRESS': '104 FOUNDERS DR',
#  'CITY': 'CONWAY',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HORRY',
#  'COUNTYFIPS': 45051,
#  'LATITUDE': 33.79912090400006,
#  'LONGITUDE': -79.01567786899994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'HTC  CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 828,
#  'POPULATION': 3212.0,
#  'SOURCE': 'https://www.coastal.edu/recreation/facilities/htccenter/',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'SC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 813,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1326.0,
#  'ZIP': '29526',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647371'),
#  'geometry': 'POINT (-8795985.0251 4001860.659599997)'}
# {'ADDRESS': '1971 UNIVERSITY BLVD',
#  'CITY': 'LYNCHBURG',
#  'COUNTRY': 'USA',
#  'COUNTY': 'LYNCHBURG',
#  'COUNTYFIPS': 51680,
#  'LATITUDE': 37.35441700000007,
#  'LONGITUDE': -79.17503599999998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'WILLIAMS STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 829,
#  'POPULATION': 25000.0,
#  'SOURCE': 'http://www.liberty.edu/flames/index.cfm?PID=38090',
#  'SOURCEDATE': '2018-10-12',
#  'STATE': 'VA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 814,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1327.0,
#  'ZIP': '24502',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647372'),
#  'geometry': 'POINT (-8813724.6911 4488623.759000003)'}
# {'ADDRESS': '3300 US 41',
#  'CITY': 'HENDERSON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'HENDERSON',
#  'COUNTYFIPS': 21101,
#  'LATITUDE': 37.91526600000003,
#  'LONGITUDE': -87.54677099999998,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'ELLIS PARK',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 830,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://ellisparkracing.com/',
#  'SOURCEDATE': '2018-10-15',
#  'STATE': 'KY',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 815,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1328.0,
#  'ZIP': '42420',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647373'),
#  'geometry': 'POINT (-9745661.9683 4567462.646200001)'}
# {'ADDRESS': '5757 US 90',
#  'CITY': 'SAN ANTONIO',
#  'COUNTRY': 'USA',
#  'COUNTY': 'BEXAR',
#  'COUNTYFIPS': 48029,
#  'LATITUDE': 29.40960800000005,
#  'LONGITUDE': -98.60165499999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'NELSON W WOLFF MUNICIPAL STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 831,
#  'POPULATION': 6200.0,
#  'SOURCE': 'http://www.milb.com/content/page.jsp?sid=t510&ymd=20060318&content_id=48476&vkey=team2',
#  'SOURCEDATE': '2018-10-15',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 816,
#  'VAL_DATE': '2018-10-15',
#  'VENUEID': 1329.0,
#  'ZIP': '78227',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647374'),
#  'geometry': 'POINT (-10976286.026 3427883.972199999)'}
# {'ADDRESS': '1100 OAK DRIVE SE',
#  'CITY': 'WASHINGTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'DISTRICT OF COLUMBIA',
#  'COUNTYFIPS': 11001,
#  'LATITUDE': 38.84693200000004,
#  'LONGITUDE': -76.99137099999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ST ELIZABETHS EAST ENTERTAINMENT AND SPORTS ARENA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 832,
#  'POPULATION': 4200.0,
#  'SOURCE': 'https://esaontherise.com/',
#  'SOURCEDATE': '2018-10-17',
#  'STATE': 'DC',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 817,
#  'VAL_DATE': '2018-10-17',
#  'VENUEID': 1330.0,
#  'ZIP': '20032',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647375'),
#  'geometry': 'POINT (-8570640.2152 4699769.5515)'}
# {'ADDRESS': '550 14TH AVE',
#  'CITY': 'SEATTLE',
#  'COUNTRY': 'USA',
#  'COUNTY': 'KING',
#  'COUNTYFIPS': 53033,
#  'LATITUDE': 47.60773900000004,
#  'LONGITUDE': -122.313225,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'REDHAWK CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 833,
#  'POPULATION': 999.0,
#  'SOURCE': 'http://www.goseattleu.com/ViewArticle.dbml?ATCLID=208002661&DB_OEM_ID=18200&DB_OEM_ID=18200',
#  'SOURCEDATE': '2018-10-17',
#  'STATE': 'WA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 818,
#  'VAL_DATE': '2018-10-17',
#  'VENUEID': 1331.0,
#  'ZIP': '98112',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647376'),
#  'geometry': 'POINT (-13615845.9243 6041842.9223000035)'}
# {'ADDRESS': '6001 UNIVERSITY BLVD',
#  'CITY': 'MOON TOWNSHIP',
#  'COUNTRY': 'USA',
#  'COUNTY': 'ALLEGHENY',
#  'COUNTYFIPS': 42003,
#  'LATITUDE': 40.52024613100008,
#  'LONGITUDE': -80.21473891699998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'UPMC EVENTS CENTER',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 835,
#  'POPULATION': 4000.0,
#  'SOURCE': 'https://www.rmu.edu/athletics/upmc-events-center?path=athletics',
#  'SOURCEDATE': '2018-10-18',
#  'STATE': 'PA',
#  'STATUS': 'UNDER CONSTRUCTION',
#  'TYPE': 'NOT AVAILABLE',
#  'Unnamed: 0': 819,
#  'VAL_DATE': '2018-10-18',
#  'VENUEID': 1332.0,
#  'ZIP': '15108',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647377'),
#  'geometry': 'POINT (-8929463.8904 4941833.551799998)'}
# {'ADDRESS': 'NOLAN RYAN EXPY',
#  'CITY': 'ARLINGTON',
#  'COUNTRY': 'USA',
#  'COUNTY': 'TARRANT',
#  'COUNTYFIPS': 48439,
#  'LATITUDE': 32.74436525500005,
#  'LONGITUDE': -97.08620842099998,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'GLOBE LIFE FIELD',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 836,
#  'POPULATION': 40000.0,
#  'SOURCE': 'https://www.mlb.com/rangers/ballpark/globe-life-field',
#  'SOURCEDATE': '2018-10-18',
#  'STATE': 'TX',
#  'STATUS': 'UNDER CONSTRUCTION',
#  'TYPE': 'NOT AVAILABLE',
#  'Unnamed: 0': 820,
#  'VAL_DATE': '2018-10-18',
#  'VENUEID': 1333.0,
#  'ZIP': '76011',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647378'),
#  'geometry': 'POINT (-10807587.2845 3861421.6766000018)'}
# {'ADDRESS': '1021 MONTEREY SALINAS HIGHWAY',
#  'CITY': 'SALINAS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'MONTEREY',
#  'COUNTYFIPS': 6053,
#  'LATITUDE': 36.584419000000025,
#  'LONGITUDE': -121.75390299999998,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'WEATHERTECH RACEWAY LAGUNA SECA',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 837,
#  'POPULATION': 11000.0,
#  'SOURCE': 'http://www.weathertechraceway.com/',
#  'SOURCEDATE': '2018-11-28',
#  'STATE': 'CA',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 821,
#  'VAL_DATE': '2018-11-28',
#  'VENUEID': 1334.0,
#  'ZIP': '93908',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647379'),
#  'geometry': 'POINT (-13553512.2908 4381243.368699998)'}
# {'ADDRESS': '9201 CIRCUIT OF THE AMERICAS BLVD',
#  'CITY': 'AUSTIN',
#  'COUNTRY': 'USA',
#  'COUNTY': 'TRAVIS',
#  'COUNTYFIPS': 48453,
#  'LATITUDE': 30.135444000000064,
#  'LONGITUDE': -97.636688,
#  'NAICS_CODE': 711212,
#  'NAICS_DESC': 'RACETRACKS',
#  'NAME': 'CIRCUIT OF THE AMERICAS',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 838,
#  'POPULATION': 120000.0,
#  'SOURCE': 'http://www.circuitoftheamericas.com/',
#  'SOURCEDATE': '2018-11-28',
#  'STATE': 'TX',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 822,
#  'VAL_DATE': '2018-11-28',
#  'VENUEID': 1335.0,
#  'ZIP': '78617',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164737a'),
#  'geometry': 'POINT (-10868589.5909 3520977.940200001)'}
# {'ADDRESS': '3333 AL DAVIS WAY',
#  'CITY': 'LAS VEGAS',
#  'COUNTRY': 'USA',
#  'COUNTY': 'CLARK',
#  'COUNTYFIPS': 32003,
#  'LATITUDE': 36.09145723200004,
#  'LONGITUDE': -115.18353398999994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'LAS VEGAS STADIUM',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 839,
#  'POPULATION': 65000.0,
#  'SOURCE': 'http://lasvegasstadium.raiders.com/',
#  'SOURCEDATE': '2019-01-06',
#  'STATE': 'NV',
#  'STATUS': 'UNDER CONSTRUCTION',
#  'TYPE': 'NOT AVAILABLE',
#  'Unnamed: 0': 823,
#  'VAL_DATE': '2019-01-06',
#  'VENUEID': 1336.0,
#  'ZIP': '89118',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164737b'),
#  'geometry': 'POINT (-12822172.3515 4313213.054399997)'}

# %% [markdown]
# # Query

# %%
df['geometry']
# Out:
# 0        POINT (-9797298.5082 5315043.943599999)
# 1       POINT (-9198320.6198 3219439.4778000005)
# 2      POINT (-13157142.7841 3997054.0565000027)
# 3         POINT (-9642382.973 3966132.843699999)
# 4             POINT (-8840529.7565 5408873.3895)
#                          ...
# 819      POINT (-8929463.8904 4941833.551799998)
# 820    POINT (-10807587.2845 3861421.6766000018)
# 821     POINT (-13553512.2908 4381243.368699998)
# 822     POINT (-10868589.5909 3520977.940200001)
# 823     POINT (-12822172.3515 4313213.054399997)
# Name: geometry, Length: 824, dtype: object

# %%
m1=df['LATITUDE'].max()
n1=df['LATITUDE'].min()

# %%
m2=df['LONGITUDE'].max()
n2=df['LONGITUDE'].min()

# %%
print(n1,"<=Latitude<=",m1)
x=float(input(print("Enter Latitude value of your choice")))
while(n1>x or x>m1):
  x=float(input("Enter valid value"))
print(n2,"<=Longitude<=",m2)
y=float(input(print("Enter Longitude value of your choice")))
while(n2>y or y>m2):
  y=float(input("Enter valid value"))
# Out:
# 17.06970000000007 <=Latitude<= 53.57133351700003
# Enter Latitude value of your choice
# 15.7
# Enter valid value18.9
# -157.92996999999997 <=Longitude<= -65.79849542099998
# Enter Longitude value of your choice
# -159.8
# Enter valid value-67.89

# %%
for i in res_db.find({'LATITUDE':{'$gt':n1 , '$lt':x}}):
    if(i['LONGITUDE']>n2 and i['LONGITUDE']<y):
      print("\n")
      pprint(i) 
    # Using urlopen() function with url in it  
      pprint('----------------------------------------------------------------------------------------------------------------')
      print("For more details about the place click on the link below")
      pprint(i['SOURCE'])
# Out:
# {'ADDRESS': 'AVENIDA VELODROMO DE LA CIUDAD DEPORTIVA S/N',
#  'CITY': 'VILLAHERMOSA',
#  'COUNTRY': 'MEX',
#  'COUNTY': 'CENTRO',
#  'COUNTYFIPS': 27004,
#  'LATITUDE': 17.976710000000026,
#  'LONGITUDE': -92.94411799999996,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'PARQUE DE BÉISBOL CENTENARIO DEL 27 DE FEBRERO',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 771,
#  'POPULATION': -999.0,
#  'SOURCE': 'https://www.olmecastabasco.net/aficion',
#  'SOURCEDATE': '2016-02-22',
#  'STATE': 'TB',
#  'STATUS': 'OPEN',
#  'TYPE': 'SINGLE USE',
#  'Unnamed: 0': 760,
#  'VAL_DATE': '2018-10-08',
#  'VENUEID': 1276.0,
#  'ZIP': '86100',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e152164733c'),
#  'geometry': 'POINT (-10346491.888 2034822.6711999997)'}
# '----------------------------------------------------------------------------------------------------------------'
# For more details click on the link below
# 'https://www.olmecastabasco.net/aficion'
#
#
# {'ADDRESS': 'AV JUAREZ S/N',
#  'CITY': 'CIUDAD DEL CARMEN',
#  'COUNTRY': 'MEX',
#  'COUNTY': 'CARMEN',
#  'COUNTYFIPS': 4003,
#  'LATITUDE': 18.647535121000036,
#  'LONGITUDE': -91.81942782399994,
#  'NAICS_CODE': 711310,
#  'NAICS_DESC': 'PROMOTERS OF PERFORMING ARTS, SPORTS, AND SIMILAR EVENTS WITH '
#                'FACILITIES',
#  'NAME': 'ESTADIO RESURGIMIENTO',
#  'NAME2': 'NOT AVAILABLE',
#  'OBJECTID': 786,
#  'POPULATION': -999.0,
#  'SOURCE': 'http://www.delfinesbeisbol.com.mx/tickets.htm',
#  'SOURCEDATE': '2016-02-22',
#  'STATE': 'CM',
#  'STATUS': 'OPEN',
#  'TYPE': 'OTHER',
#  'Unnamed: 0': 771,
#  'VAL_DATE': '2018-10-09',
#  'VENUEID': 1272.0,
#  'ZIP': '24166',
#  'ZIP4': 'NOT AVAILABLE',
#  '_id': ObjectId('62481201b6891e1521647347'),
#  'geometry': 'POINT (-10221291.9503 2113482.5133000016)'}
# '----------------------------------------------------------------------------------------------------------------'
# For more details click on the link below
# 'http://www.delfinesbeisbol.com.mx/tickets.htm'
