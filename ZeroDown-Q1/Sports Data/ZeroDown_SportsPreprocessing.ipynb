# %%
# !pip install geopandas

# %%
import geopandas  as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
shapefile_path = r"/content/drive/MyDrive/zero/Major_Sport_Venues/MajorSportVenues.shp"
df = gpd.read_file(shapefile_path)

# %%
df
# Out:
#      OBJECTID  VENUEID                             NAME  \
# 0           1      1.0                   MILWAUKEE MILE
# 1           2     16.0        STREETS OF ST. PETERSBURG
# 2           3     17.0            STREETS OF LONG BEACH
# 3           4     18.0          BARBER MOTORSPORTS PARK
# 4           5     20.0               STREETS OF TORONTO
# ..        ...      ...                              ...
# 819       835   1332.0               UPMC EVENTS CENTER
# 820       836   1333.0                 GLOBE LIFE FIELD
# 821       837   1334.0  WEATHERTECH RACEWAY LAGUNA SECA
# 822       838   1335.0          CIRCUIT OF THE AMERICAS
# 823       839   1336.0                LAS VEGAS STADIUM
#
#                                ADDRESS              CITY STATE      ZIP  \
# 0                640 SOUTH 84TH STREET        WEST ALLIS    WI    53214
# 1                    BAYSHORE DRIVE SE  SAINT PETERSBURG    FL    33701
# 2             300 EAST OCEAN BOULEVARD        LONG BEACH    CA    90802
# ...

# %%
df['SOURCE'].unique()

# %%
df['NAICS_CODE'].unique()
# Out:
# array(['711212', '711310', '713910'], dtype=object)

# %%
df.columns
# Out:
# Index(['OBJECTID', 'VENUEID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE', 'NAME2',
#        'NAME3', 'FORMERNM', 'YEARCHNG', 'geometry'],
#       dtype='object')

# %% [markdown]
# Zip 4 dropped

# %%
df.drop(columns = ['VAL_METHOD','NAME3','FORMERNM','YEARCHNG','TELEPHONE'],inplace=True)

# %%
df
# Out:
#      OBJECTID  VENUEID                             NAME  \
# 0           1      1.0                   MILWAUKEE MILE
# 1           2     16.0        STREETS OF ST. PETERSBURG
# 2           3     17.0            STREETS OF LONG BEACH
# 3           4     18.0          BARBER MOTORSPORTS PARK
# 4           5     20.0               STREETS OF TORONTO
# ..        ...      ...                              ...
# 819       835   1332.0               UPMC EVENTS CENTER
# 820       836   1333.0                 GLOBE LIFE FIELD
# 821       837   1334.0  WEATHERTECH RACEWAY LAGUNA SECA
# 822       838   1335.0          CIRCUIT OF THE AMERICAS
# 823       839   1336.0                LAS VEGAS STADIUM
#
#                                ADDRESS              CITY STATE      ZIP  \
# 0                640 SOUTH 84TH STREET        WEST ALLIS    WI    53214
# 1                    BAYSHORE DRIVE SE  SAINT PETERSBURG    FL    33701
# 2             300 EAST OCEAN BOULEVARD        LONG BEACH    CA    90802
# ...

# %%
#DataCleaning
#1.checking for null values in the first column
df=df.dropna(axis=0)
r,c=df.shape
print(r,c)
df.isnull()
# Out:
# 824 23
#      OBJECTID  VENUEID   NAME  ADDRESS   CITY  STATE    ZIP   ZIP4   TYPE  \
# 0       False    False  False    False  False  False  False  False  False
# 1       False    False  False    False  False  False  False  False  False
# 2       False    False  False    False  False  False  False  False  False
# 3       False    False  False    False  False  False  False  False  False
# 4       False    False  False    False  False  False  False  False  False
# ..        ...      ...    ...      ...    ...    ...    ...    ...    ...
# 819     False    False  False    False  False  False  False  False  False
# 820     False    False  False    False  False  False  False  False  False
# 821     False    False  False    False  False  False  False  False  False
# 822     False    False  False    False  False  False  False  False  False
# 823     False    False  False    False  False  False  False  False  False
#
# ...

# %%
#checking for percentage of null values in each column
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# OBJECTID - 0%
# VENUEID - 0%
# NAME - 0%
# ADDRESS - 0%
# CITY - 0%
# STATE - 0%
# ZIP - 0%
# ZIP4 - 0%
# TYPE - 0%
# STATUS - 0%
# POPULATION - 0%
# COUNTY - 0%
# COUNTYFIPS - 0%
# COUNTRY - 0%
# LATITUDE - 0%
# LONGITUDE - 0%
# NAICS_CODE - 0%
# NAICS_DESC - 0%
# SOURCE - 0%
# SOURCEDATE - 0%
# VAL_DATE - 0%
# NAME2 - 0%
# geometry - 0%

# %%
df.to_csv('sports.csv')
