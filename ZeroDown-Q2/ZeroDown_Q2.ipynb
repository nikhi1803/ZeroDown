# %%
# !pip install geopandas

# %%
# !pip install dnspython

# %%
# !pip install pymongo

# %%
import pymongo
import json
import pandas as pd
from pprint import pprint
import numpy as np

# %%
data=pd.read_csv('/content/final.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            SID  SEASON  NUMBER BASIN SUBBASIN  \
# 0           0             0  2022080S13114    2022      18    SI       WA
# 1           1             1  2022080S13114    2022      18    SI       WA
# 2           2             2  2022080S13114    2022      18    SI       WA
# 3           3             3  2022080S13114    2022      18    SI       WA
# 4           4             4  2022080S13114    2022      18    SI       WA
#
#         NAME             ISO_TIME NATURE  ...  BOM_CI  STORM_SPD STORM_DR  \
# 0  CHARLOTTE  2022-03-20 12:00:00     NR  ...  -999.9         13      259
# 1  CHARLOTTE  2022-03-20 15:00:00     NR  ...  -999.9         12      251
# 2  CHARLOTTE  2022-03-20 18:00:00     NR  ...  -999.9         13      230
# 3  CHARLOTTE  2022-03-20 21:00:00     NR  ...  -999.9         14      215
# 4  CHARLOTTE  2022-03-21 00:00:00     NR  ...  -999.9         12      217
#
#    year  month day hour  min  \
# 0  2022      3  20   12    0
# ...

# %%
client=pymongo.MongoClient("mongodb+srv://19pd12:Shreya_123@cluster0.oekib.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
df=pd.read_csv("/content/final.csv")

# %%
df_slice.head()
# Out:
#         SEASON  NUMBER BASIN SUBBASIN    NAME             ISO_TIME NATURE  \
# 834       2019      10    WP       MM   WUTIP  2019-02-23 06:00:00     TS
# 234853    2012      49    WP       MM  TEMBIN  2012-08-27 18:00:00     TS
# 229284    2011      55    WP       MM   TALAS  2011-08-28 12:00:00     TS
# 215143    2009      99    SI       WA   BILLY  2008-12-24 03:00:00     TS
# 293945    2022      10    SI       MM  EMNATI  2022-02-22 00:00:00     NR
#
#           LAT     LON   TRACK_TYPE  ...  BOM_CI  STORM_SPD STORM_DR  year  \
# 834     11.40  143.25         main  ...  -999.9          9      327  2019
# 234853  21.80  120.92         main  ...  -999.9         12       53  2012
# 229284  23.25  140.07         main  ...  -999.9          3       37  2011
# 215143 -17.82  119.55         main  ...  -999.9          6      274  2008
# 293945 -19.40   51.30  PROVISIONAL  ...  -999.9         11      233  2022
#
#         month  day  hour  min  \
# 834         2   23     6    0
# ...

# %%
df_slice = df.sample(frac=0.5)

# %%
df_slice.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'SID', 'SEASON', 'NUMBER', 'BASIN',
#        'SUBBASIN', 'NAME', 'ISO_TIME', 'NATURE', 'LAT', 'LON', 'TRACK_TYPE',
#        'DIST2LAND', 'LANDFALL', 'IFLAG', 'USA_ATCFID', 'USA_LAT', 'USA_LON',
#        'USA_WIND', 'USA_PRES', 'USA_SSHS', 'USA_POCI', 'USA_ROCI', 'USA_RMW',
#        'NEW_CI', 'REU_TNUM', 'REU_CI', 'BOM_TNUM', 'BOM_CI', 'STORM_SPD',
#        'STORM_DR', 'year', 'month', 'day', 'hour', 'min', 'geometry',
#        'Datetime'],
#       dtype='object')

# %%
df_slice.drop(columns=['Unnamed: 0','Unnamed: 0.1','SID'],inplace=True)

# %%
#DataCleaning
#1.checking for null values in the first column
df_slice=df_slice.dropna(axis=0)
r,c=df_slice.shape
print(r,c)
df_slice.isnull()
# Out:
# 42767 36
#         SEASON  NUMBER  BASIN  SUBBASIN   NAME  ISO_TIME  NATURE    LAT  \
# 834      False   False  False     False  False     False   False  False
# 234853   False   False  False     False  False     False   False  False
# 229284   False   False  False     False  False     False   False  False
# 215143   False   False  False     False  False     False   False  False
# 293945   False   False  False     False  False     False   False  False
# ...        ...     ...    ...       ...    ...       ...     ...    ...
# 239412   False   False  False     False  False     False   False  False
# 265600   False   False  False     False  False     False   False  False
# 274146   False   False  False     False  False     False   False  False
# 222155   False   False  False     False  False     False   False  False
# 245115   False   False  False     False  False     False   False  False
#
#           LON  TRACK_TYPE  ...  BOM_CI  STORM_SPD  STORM_DR   year  month  \
# ...

# %%
#checking for percentage of null values in each column
for col in df_slice.columns:
    pct_missing = np.mean(df_slice[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# SEASON - 0%
# NUMBER - 0%
# BASIN - 0%
# SUBBASIN - 0%
# NAME - 0%
# ISO_TIME - 0%
# NATURE - 0%
# LAT - 0%
# LON - 0%
# TRACK_TYPE - 0%
# DIST2LAND - 0%
# LANDFALL - 0%
# IFLAG - 0%
# USA_ATCFID - 0%
# USA_LAT - 0%
# USA_LON - 0%
# USA_WIND - 0%
# USA_PRES - 0%
# USA_SSHS - 0%
# USA_POCI - 0%
# USA_ROCI - 0%
# USA_RMW - 0%
# NEW_CI - 0%
# REU_TNUM - 0%
# REU_CI - 0%
# BOM_TNUM - 0%
# BOM_CI - 0%
# STORM_SPD - 0%
# STORM_DR - 0%
# year - 0%
# month - 0%
# day - 0%
# hour - 0%
# min - 0%
# geometry - 0%
# Datetime - 0%

# %%
df_slice.shape
# Out:
# (42767, 36)

# %%
data=df_slice.to_dict(orient='records')

# %%
db_slice=client['ZeroDownfinal_Q2']

# %%
print(db_slice)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.oekib.mongodb.net:27017', 'cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDownfinal_Q2')

# %%
db_slice.df4.insert_many(data)

# %%
client.list_database_names()
# Out:
# ['ZeroDown1_convention',
#  'ZeroDown1_sports',
#  'ZeroDownfinal_Q2',
#  'h3',
#  'sample_airbnb',
#  'sample_analytics',
#  'admin',
#  'local']

# %%
data_q2= client.ZeroDownfinal_Q2

# %%
data_q2
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.oekib.mongodb.net:27017', 'cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDownfinal_Q2')

# %%
res_db = data_q2.df4

# %%
res_db
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.oekib.mongodb.net:27017', 'cluster0-shard-00-00.oekib.mongodb.net:27017', 'cluster0-shard-00-01.oekib.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-sro1xp-shard-0', tls=True), 'ZeroDownfinal_Q2'), 'df4')

# %% [markdown]
# # Data

# %%
df_slice
# Out:
#         SEASON  NUMBER BASIN SUBBASIN     NAME             ISO_TIME NATURE  \
# 834       2019      10    WP       MM    WUTIP  2019-02-23 06:00:00     TS
# 234853    2012      49    WP       MM   TEMBIN  2012-08-27 18:00:00     TS
# 229284    2011      55    WP       MM    TALAS  2011-08-28 12:00:00     TS
# 215143    2009      99    SI       WA    BILLY  2008-12-24 03:00:00     TS
# 293945    2022      10    SI       MM   EMNATI  2022-02-22 00:00:00     NR
# ...        ...     ...   ...      ...      ...                  ...    ...
# 239412    2013      25    WP       MM     YAGI  2013-06-12 00:00:00     TS
# 265600    2017      57    WP       MM   BANYAN  2017-08-11 12:00:00     TS
# 274146    2018      93    EP       MM   SERGIO  2018-10-06 06:00:00     TS
# 222155    2010      18    WP       MM    OMAIS  2010-03-26 03:00:00     TS
# 245115    2014      19    SI       WA  GILLIAN  2014-03-26 09:00:00     TS
#
# ...

# %%
for i in res_db.find():
  pprint(i)
  break
# Out:
# {'BASIN': 'WP',
#  'BOM_CI': -999.9,
#  'BOM_TNUM': -999.9,
#  'DIST2LAND': 1556,
#  'Datetime': '2019-02-23 06:00:00',
#  'IFLAG': 'OOOO__________',
#  'ISO_TIME': '2019-02-23 06:00:00',
#  'LANDFALL': 1556,
#  'LAT': 11.4,
#  'LON': 143.25,
#  'NAME': 'WUTIP',
#  'NATURE': 'TS',
#  'NEW_CI': -999.9,
#  'NUMBER': 10,
#  'REU_CI': -999.9,
#  'REU_TNUM': -999.9,
#  'SEASON': 2019,
#  'STORM_DR': 327,
#  'STORM_SPD': 9,
#  'SUBBASIN': 'MM',
#  'TRACK_TYPE': 'main',
#  'USA_ATCFID': 'WP022019',
#  'USA_LAT': 11.4,
#  'USA_LON': 143.2,
#  'USA_POCI': 1006.0,
#  'USA_PRES': 943.0,
#  'USA_RMW': 12.0,
#  'USA_ROCI': 230.0,
#  'USA_SSHS': 4,
#  'USA_WIND': 115.0,
#  '_id': ObjectId('6248840e401cd5b286804bfb'),
#  'day': 23,
#  'geometry': 'LINESTRING (143.25 11.399999618530273, 142.999755859375 '
#              '11.746692657470703)',
#  'hour': 6,
#  'min': 0,
#  'month': 2,
#  'year': 2019}

# %% [markdown]
# # Query

# %%
m1=df_slice['LAT'].max()
n1=df_slice['LAT'].min()

# %%
m2=df['LON'].max()
n2=df['LON'].min()

# %% [markdown]
# Q1-Total number of places lying in the user given latitude and longitude range

# %%
print(n1,"<=Latitude<=",m1)
x=float(input(print("Enter Latitude value of your choice")))
while(n1>x or x>m1):
  x=float(input("Enter valid value"))
print(n2,"<=Longitude<=",m2)
y=float(input(print("Enter Longitude value of your choice")))
while(n2>y or y>m2):
  y=float(input("Enter valid value"))
# Out:
# -44.34 <=Latitude<= 61.13
# Enter Latitude value of your choice
# 36
# -179.75 <=Longitude<= 266.9
# Enter Longitude value of your choice
# 34

# %%
count=0
for i in res_db.find({'LAT':{'$gt':n1 , '$lt':x}}):
    if(i['LON']>n2 and i['LON']<y):
      count+=1
print("There are totally",count,"places in the range of",x,"and",y)
# Out:
# There are totally 10618 places in the range of 36.0 and 34.0

# %% [markdown]
# Q2-Printing name of the hurricane occured during user specified date

# %%
for i in res_db.aggregate([{"$group" : {"_id" : "$year", "Hurricane_Names" : {"$push" : "$NAME"}}}]):
  print(i)
  print("\n")
# Out:
# {'_id': 2006, 'Hurricane_Names': ['KAEMI', 'KAEMI', 'CIMARON', 'ELIA', 'CLARE', 'WUKONG', 'BOPHA', 'YAGI', 'NOT_NAMED', 'JELAWAT', 'JOHN', 'CHEBI', 'SHANSHAN', 'WATI', 'PRAPIROON', 'XAVIER', 'WUKONG', 'JIM', 'DANIEL', 'CHANCHU', 'ELIA', 'BOLOETSE', 'CHANCHU', 'MUKDA', 'WUKONG', 'NOT_NAMED', 'YAGI', 'MARIA', 'YANI', 'IOKE', 'DANIEL', 'TRAMI', 'UTOR', 'ELIA', 'KAEMI', 'UTOR', 'NOT_NAMED', 'MARIA', 'SERGIO', 'NOT_NAMED', 'NORMAN', 'DANIEL', 'EWINIAR', 'BONDO', 'BUD', 'CHANCHU', 'BOPHA', 'ALETTA', 'IOKE', 'CIMARON', 'SERGIO', 'CARINA', 'SERGIO', 'SERGIO', 'DURIAN', 'EMILIA', 'NOT_NAMED', 'PAUL', 'BOLOETSE', 'SHANSHAN', 'ALETTA', 'FABIO', 'DANIEL', 'SHANSHAN', 'CARINA', 'CIMARON', 'ALETTA', 'GILMA', 'YAGI', 'CHEBI', 'SHANSHAN', 'WUKONG', 'IOKE', 'KRISTY', 'CHANCHU', 'PRAPIROON', 'IOKE', 'XANGSANE', 'SAOMAI', 'CARINA', 'BUD', 'PAUL', 'SHANSHAN', 'DIWA', 'MALA', 'WUKONG', 'IOKE', 'BILIS', 'FLOYD', 'OLIVIA', 'SHANSHAN', 'SHANSHAN', 'BOLOETSE', 'JIM', 'IOKE', 'KRISTY', 'RUMBIA', 'SAOMAI', 'EW
# ...
